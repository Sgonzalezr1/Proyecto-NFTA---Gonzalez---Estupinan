# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 26.4 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %%
import pandas as pd

# %%
df = pd.read_excel("Datos Demanda.xlsx")

# Extraer los valores de la columna 5 (índice 4, ya que los índices comienzan en 0)
Tasa_Panzenu_1 = df["Tasa Panzenu Sentido 1"].tolist()

# Mostrar la lista
print(Tasa_Panzenu_1)
len(Tasa_Panzenu_1)
# Out:
# [0.8, 1.0, 1.1, 1.3, 1.4, 1.6, 1.7, 1.8, 2.0, 2.1, 2.2, 2.3, 2.4, 2.4, 2.5, 2.6, 2.6, 2.7, 2.7, 2.7, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.8, 2.8, 2.8, 2.9, 2.9, 2.9, 3.0, 3.0, 3.1, 3.1, 3.2, 3.2, 3.2, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.2, 3.1, 3.0, 3.0, 2.9, 2.7, 2.6, 2.5, 2.3, 2.2, 2.1, 1.9, 1.8, 1.6, 1.5, 1.4, 1.2, 1.1, 1.0, 0.9, 0.8]
# 96

# %%
Tasa_Panzenu = Tasa_Panzenu_1[::-1]

print(Tasa_Panzenu)
# Out:
# [0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.5, 1.6, 1.8, 1.9, 2.1, 2.2, 2.3, 2.5, 2.6, 2.7, 2.9, 3.0, 3.0, 3.1, 3.2, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.2, 3.2, 3.2, 3.1, 3.1, 3.0, 3.0, 2.9, 2.9, 2.9, 2.8, 2.8, 2.8, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.7, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.7, 2.7, 2.7, 2.6, 2.6, 2.5, 2.4, 2.4, 2.3, 2.2, 2.1, 2.0, 1.8, 1.7, 1.6, 1.4, 1.3, 1.1, 1.0, 0.8]

# %%
Tasa_Panzenu_2 = []

# Llenar la nueva lista según las condiciones
for i in range(len(Tasa_Panzenu)):
    if i < 32:
        Tasa_Panzenu_2.append(Tasa_Panzenu[i])  # Dividir entre 2
    elif 32 <= i < 64:
        Tasa_Panzenu_2.append(Tasa_Panzenu[i] * 2)  # Multiplicar por 2
    else:
        Tasa_Panzenu_2.append(Tasa_Panzenu[i])  # Dividir entre 2

print(Tasa_Panzenu_2)
# Out:
# [0.8, 0.9, 1.0, 1.1, 1.2, 1.4, 1.5, 1.6, 1.8, 1.9, 2.1, 2.2, 2.3, 2.5, 2.6, 2.7, 2.9, 3.0, 3.0, 3.1, 3.2, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.3, 3.2, 3.2, 6.4, 6.2, 6.2, 6.0, 6.0, 5.8, 5.8, 5.8, 5.6, 5.6, 5.6, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.4, 5.6, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.8, 2.7, 2.7, 2.7, 2.6, 2.6, 2.5, 2.4, 2.4, 2.3, 2.2, 2.1, 2.0, 1.8, 1.7, 1.6, 1.4, 1.3, 1.1, 1.0, 0.8]

# %%
tasas_Panzenu= [[Tasa_Panzenu_1[i], Tasa_Panzenu_2[i]] for i in range(len(Tasa_Panzenu_1))]
print(tasas_Panzenu)
# Out:
# [[0.8, 0.8], [1.0, 0.9], [1.1, 1.0], [1.3, 1.1], [1.4, 1.2], [1.6, 1.4], [1.7, 1.5], [1.8, 1.6], [2.0, 1.8], [2.1, 1.9], [2.2, 2.1], [2.3, 2.2], [2.4, 2.3], [2.4, 2.5], [2.5, 2.6], [2.6, 2.7], [2.6, 2.9], [2.7, 3.0], [2.7, 3.0], [2.7, 3.1], [2.8, 3.2], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.3], [2.8, 3.2], [2.8, 3.2], [2.8, 6.4], [2.7, 6.2], [2.7, 6.2], [2.7, 6.0], [2.7, 6.0], [2.7, 5.8], [2.7, 5.8], [2.7, 5.8], [2.7, 5.6], [2.7, 5.6], [2.7, 5.6], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.7, 5.4], [2.8, 5.4], [2.8, 5.4], [2.8, 5.4], [2.9, 5.4], [2.9, 5.4], [2.9, 5.4], [3.0, 5.4], [3.0, 5.4], [3.1, 5.4], [3.1, 5.4], [3.2, 5.6], [3.2, 2.8], [3.2, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.3, 2.8], [3.2, 2.8], [3.1, 2.7], [3.0, 2.7], [3.0, 2.7], [2.9, 2.6], [2.7, 2.6], [2.6, 2.5], [2.5, 2.4], [2.3, 2.4], [2.2, 2.3], [2.1, 2.2], [1.9, 2.1], [1.8, 2.0], [1.6, 1.8], [1.5, 1.7], [1.4, 1.6], [1.2, 1.4], [1.1, 1.3], [1.0, 1.1], [0.9, 1.0], [0.8, 0.8]]

# %%
import pulp
import time
start_time = time.time()
# Parámetros
m = 96
n=[6,8]
alpha = 10
t_ruta = 40
t_min = 5
h_min = 5
h_max = 15
C = 45
F=2
 # Tasa de llegada de pasajeros por intervalo, para cada sentido

# Crear el problema de optimización
prob = pulp.LpProblem("Despacho_de_Buses", pulp.LpMinimize)

# Variables de decisión
x = pulp.LpVariable.dicts("x", ((i, t,f) for f in range(F)for i in range(n[f]) for t in range(m)), cat='Binary')
b = pulp.LpVariable.dicts("b", ((t,f) for t in range(m) for f in range(F) ), lowBound=0)
w = pulp.LpVariable.dicts("w", ((t,f)for t in range(m) for f in range(F) ), lowBound=0)
delta = pulp.LpVariable.dicts("delta", ((t,f) for t in range(m) for f in range(F)), lowBound=0)

# Función objetivo
prob += pulp.lpSum(w[t,f] for t in range (m) for f in range(F)), "Minimize_total_waiting_passengers"

# Restricciones
#Pasajeros abordando en cada periodo t y sentido f
for t in range(m):
  for f in range(F):
      prob+=delta[t,f]== tasas_Panzenu[t][f]*alpha

#En cada periodo t del sentido f solo puede ser asignado un bus i
for t in range(m):
  for f in range(F):
      prob+=pulp.lpSum(x[i,t,f]for i in range(n[f]))<=1

# La cantidad de personas esperando en el primer intervalo es igual a la cantidad de personas abordando en ese intervalo
for f in range(F):
    prob += w[0,f] == delta[0,f]

# Restricción de pasajeros esperando en intervalos t > 0
for t in range(1, m):
  for f in range(F):
      prob += w[t,f] == w[t - 1,f]+ delta[t - 1,f] - b[t,f]

# Capacidad de abordaje en cada intervalo
for t in range(m):
  for f in range(F):
     prob += b[t,f] <= pulp.lpSum(x[i,t,f] * C for i in range(n[f]))

# Restringir los intervalos en los que se asigna un mismo bus i
for f in range(F):
    for i in range(n[f]):  # Para cada bus
        for t in range(m):  # Para cada intervalo `t`
            # Calcula el número de intervalos que representan los tiempos mínimos y máximos
            tiempo_min_intervalos = int((2 * t_ruta + 2 * t_min) / alpha)
            tiempo_max_intervalos = int((2 * t_ruta + 2 * t_min + 2 * h_max) / alpha)
            # Si se ha asignado un bus i en el intervalo t, ese mismo bus no puede volver a ser asignado a otro intervalo hasta no cumplir con el tiempo minimo
            for k in range(1, tiempo_min_intervalos):
                if t + k < m:  # Asegúrate de no exceder el número de intervalos
                   prob += x[i, t,f] + x[i, t + k,f] <= 1
            # Asegurar que el despacho se produzca en el rango permitido
            if t - tiempo_max_intervalos >= 0:
                prob += pulp.lpSum(x[i, t - k, f] for k in range(tiempo_min_intervalos, tiempo_max_intervalos + 1)) >= x[i, t, f]

# Restringir el despacho del bus i
for f in range(F):  # Para cada sentido
    for i in range(n[f]):  # Para cada bus
        for t in range(m):  # Para cada intervalo `t`
            # Si el bus i se despacha en el intervalo t, asegurarse de que todos los buses anteriores ya se han despachado
            if i > 0:  # Asegúrate de no evaluar el primer bus
                prob += pulp.lpSum(x[j, t_j, f] for j in range(i) for t_j in range(t)) >= x[i, t, f]

#Restringir el despacho de dos buses diferentes
for f in range(F):
  for i in range(1, n[f]):  # Para cada bus `i`, comenzando desde el segundo (ya que `j` es el anterior)
      j = i - 1  # `j` es el bus anterior al bus `i`
      for t in range(m):  # Para cada intervalo `t`
         # Calcula los intervalos para `h_min` y `h_max`
         min_intervalos = int(h_min / alpha)
         max_intervalos = int(h_max / alpha)
         # Asegurar que si el bus `i` está en el intervalo `t`, el bus `j` se debio asignar en algún intervalo entre [t - max_intervalos, t - min_intervalos]
         if t - max_intervalos >= 0:  # Verifica que el rango esté dentro de los límites de `m`
            prob += x[i, t,f] <= pulp.lpSum(x[j, t - k,f] for k in range(min_intervalos, max_intervalos + 1))

#Restringir el primer despacho
for f in range(F):
  #El primer despacho del primer bus debe asignarse entre [h_min, h_max]
  prob += pulp.lpSum(x[0, t,f] for t in range(int(h_min/alpha), int(h_max/alpha) + 1)) >= 1

#El ultimo despacho que se asigne debe asegurar que el bus logra realizar toda la ruta antes de que se termine el ultimo intervalo
t_ruta_intervals = int(t_ruta / alpha)
#Calcular el límite de intervalos
t_limite = m - (t_ruta_intervals)
for f in range(F):
  for t in range(t_limite, m):
    for i in range(n[f]):
        prob += x[i, t,f] == 0


# Resolviendo el problema con el solucionador personalizado
prob.solve()  # Activa la salida de mensajes

# Resultados
print("Estado de la solución:", pulp.LpStatus[prob.status])
print("Cantidad mínima de pasajeros esperando:", pulp.value(prob.objective))
print("\nAsignaciones de servicios:")
for f in range(F):
    for i in range(n[f]):
      for t in range(m):
          if pulp.value(x[ i, t,f]) == 1:
             print(f" Bus {i}, Intervalo {t}, Sentido{f}")

print("\nPasajeros abordando por intervalo y sentido:")
for t in range(m):
  for f in range(F):
     print(f"Intervalo {t}, Sentido{f}: {pulp.value(b[t,f])}")
print("\nPasajeros que llegaron:")
for t in range(m):
  for f in range(F):
     print(f"Intervalo {t}, Sentido{f}, : {pulp.value(delta[t,f])}")

print("\nPasajeros esperando por intervalo y sentido:")
for t in range(m):
  for f in range(F):
     print(f"Intervalo {t}, Sentido{f}: {pulp.value(w[t,f])}")
end_time = time.time()

print("Tiempo de CPU: {:.2f} segundos".format(end_time - start_time))
# Out:
# Estado de la solución: Optimal
# Cantidad mínima de pasajeros esperando: 21803.0
#
# Asignaciones de servicios:
#  Bus 0, Intervalo 0, Sentido0
#  Bus 0, Intervalo 9, Sentido0
#  Bus 0, Intervalo 18, Sentido0
#  Bus 0, Intervalo 27, Sentido0
#  Bus 0, Intervalo 36, Sentido0
#  Bus 0, Intervalo 45, Sentido0
#  Bus 0, Intervalo 54, Sentido0
#  Bus 0, Intervalo 63, Sentido0
#  Bus 0, Intervalo 72, Sentido0
#  Bus 0, Intervalo 81, Sentido0
#  Bus 0, Intervalo 90, Sentido0
#  Bus 1, Intervalo 1, Sentido0
#  Bus 1, Intervalo 10, Sentido0
#  Bus 1, Intervalo 19, Sentido0
#  Bus 1, Intervalo 28, Sentido0
#  Bus 1, Intervalo 37, Sentido0
#  Bus 1, Intervalo 46, Sentido0
#  Bus 1, Intervalo 55, Sentido0
#  Bus 1, Intervalo 64, Sentido0
#  Bus 1, Intervalo 73, Sentido0
#  Bus 1, Intervalo 82, Sentido0
#  Bus 1, Intervalo 91, Sentido0
#  Bus 2, Intervalo 2, Sentido0
#  Bus 2, Intervalo 11, Sentido0
#  Bus 2, Intervalo 20, Sentido0
#  Bus 2, Intervalo 29, Sentido0
#  Bus 2, Intervalo 38, Sentido0
#  Bus 2, Intervalo 47, Sentido0
#  Bus 2, Intervalo 56, Sentido0
#  Bus 2, Intervalo 65, Sentido0
#  Bus 2, Intervalo 74, Sentido0
#  Bus 2, Intervalo 83, Sentido0
#  Bus 3, Intervalo 3, Sentido0
#  Bus 3, Intervalo 12, Sentido0
#  Bus 3, Intervalo 21, Sentido0
#  Bus 3, Intervalo 30, Sentido0
#  Bus 3, Intervalo 39, Sentido0
#  Bus 3, Intervalo 48, Sentido0
#  Bus 3, Intervalo 57, Sentido0
#  Bus 3, Intervalo 66, Sentido0
#  Bus 3, Intervalo 75, Sentido0
#  Bus 3, Intervalo 84, Sentido0
#  Bus 4, Intervalo 4, Sentido0
#  Bus 4, Intervalo 13, Sentido0
#  Bus 4, Intervalo 22, Sentido0
#  Bus 4, Intervalo 31, Sentido0
#  Bus 4, Intervalo 40, Sentido0
#  Bus 4, Intervalo 49, Sentido0
#  Bus 4, Intervalo 58, Sentido0
#  Bus 4, Intervalo 67, Sentido0
#  Bus 4, Intervalo 76, Sentido0
#  Bus 4, Intervalo 85, Sentido0
#  Bus 5, Intervalo 5, Sentido0
#  Bus 5, Intervalo 14, Sentido0
#  Bus 5, Intervalo 23, Sentido0
#  Bus 5, Intervalo 32, Sentido0
#  Bus 5, Intervalo 41, Sentido0
#  Bus 5, Intervalo 50, Sentido0
#  Bus 5, Intervalo 59, Sentido0
#  Bus 5, Intervalo 68, Sentido0
#  Bus 5, Intervalo 77, Sentido0
#  Bus 5, Intervalo 86, Sentido0
#  Bus 0, Intervalo 1, Sentido1
#  Bus 0, Intervalo 12, Sentido1
#  Bus 0, Intervalo 21, Sentido1
#  Bus 0, Intervalo 30, Sentido1
#  Bus 0, Intervalo 39, Sentido1
#  Bus 0, Intervalo 48, Sentido1
#  Bus 0, Intervalo 57, Sentido1
#  Bus 0, Intervalo 66, Sentido1
#  Bus 0, Intervalo 75, Sentido1
#  Bus 0, Intervalo 84, Sentido1
#  Bus 1, Intervalo 2, Sentido1
#  Bus 1, Intervalo 13, Sentido1
#  Bus 1, Intervalo 22, Sentido1
#  Bus 1, Intervalo 31, Sentido1
#  Bus 1, Intervalo 40, Sentido1
#  Bus 1, Intervalo 49, Sentido1
#  Bus 1, Intervalo 58, Sentido1
#  Bus 1, Intervalo 67, Sentido1
#  Bus 1, Intervalo 76, Sentido1
#  Bus 1, Intervalo 85, Sentido1
#  Bus 2, Intervalo 3, Sentido1
#  Bus 2, Intervalo 14, Sentido1
#  Bus 2, Intervalo 23, Sentido1
#  Bus 2, Intervalo 32, Sentido1
#  Bus 2, Intervalo 41, Sentido1
#  Bus 2, Intervalo 50, Sentido1
#  Bus 2, Intervalo 59, Sentido1
#  Bus 2, Intervalo 68, Sentido1
#  Bus 2, Intervalo 77, Sentido1
#  Bus 2, Intervalo 86, Sentido1
#  Bus 3, Intervalo 4, Sentido1
#  Bus 3, Intervalo 15, Sentido1
#  Bus 3, Intervalo 24, Sentido1
#  Bus 3, Intervalo 33, Sentido1
#  Bus 3, Intervalo 42, Sentido1
#  Bus 3, Intervalo 51, Sentido1
#  Bus 3, Intervalo 60, Sentido1
#  Bus 3, Intervalo 69, Sentido1
#  Bus 3, Intervalo 78, Sentido1
#  Bus 3, Intervalo 87, Sentido1
#  Bus 4, Intervalo 5, Sentido1
#  Bus 4, Intervalo 16, Sentido1
#  Bus 4, Intervalo 25, Sentido1
#  Bus 4, Intervalo 34, Sentido1
#  Bus 4, Intervalo 43, Sentido1
#  Bus 4, Intervalo 52, Sentido1
#  Bus 4, Intervalo 61, Sentido1
#  Bus 4, Intervalo 70, Sentido1
#  Bus 4, Intervalo 79, Sentido1
#  Bus 4, Intervalo 88, Sentido1
#  Bus 5, Intervalo 6, Sentido1
#  Bus 5, Intervalo 17, Sentido1
#  Bus 5, Intervalo 26, Sentido1
#  Bus 5, Intervalo 35, Sentido1
#  Bus 5, Intervalo 44, Sentido1
#  Bus 5, Intervalo 53, Sentido1
#  Bus 5, Intervalo 62, Sentido1
#  Bus 5, Intervalo 71, Sentido1
#  Bus 5, Intervalo 80, Sentido1
#  Bus 5, Intervalo 89, Sentido1
#  Bus 6, Intervalo 7, Sentido1
#  Bus 6, Intervalo 18, Sentido1
#  Bus 6, Intervalo 27, Sentido1
#  Bus 6, Intervalo 36, Sentido1
#  Bus 6, Intervalo 45, Sentido1
#  Bus 6, Intervalo 54, Sentido1
#  Bus 6, Intervalo 63, Sentido1
#  Bus 6, Intervalo 72, Sentido1
#  Bus 6, Intervalo 81, Sentido1
#  Bus 6, Intervalo 90, Sentido1
#  Bus 7, Intervalo 8, Sentido1
#  Bus 7, Intervalo 19, Sentido1
#  Bus 7, Intervalo 28, Sentido1
#  Bus 7, Intervalo 37, Sentido1
#  Bus 7, Intervalo 46, Sentido1
#  Bus 7, Intervalo 55, Sentido1
#  Bus 7, Intervalo 64, Sentido1
#  Bus 7, Intervalo 73, Sentido1
#  Bus 7, Intervalo 82, Sentido1
#  Bus 7, Intervalo 91, Sentido1
#
# Pasajeros abordando por intervalo y sentido:
# Intervalo 0, Sentido0: 0.0
# Intervalo 0, Sentido1: 0.0
# Intervalo 1, Sentido0: 16.0
# Intervalo 1, Sentido1: 16.0
# Intervalo 2, Sentido0: 10.0
# Intervalo 2, Sentido1: 9.0
# Intervalo 3, Sentido0: 11.0
# Intervalo 3, Sentido1: 10.0
# Intervalo 4, Sentido0: 13.0
# Intervalo 4, Sentido1: 11.0
# Intervalo 5, Sentido0: 14.0
# Intervalo 5, Sentido1: 12.0
# Intervalo 6, Sentido0: 0.0
# Intervalo 6, Sentido1: 14.0
# Intervalo 7, Sentido0: 0.0
# Intervalo 7, Sentido1: 15.0
# Intervalo 8, Sentido0: 0.0
# Intervalo 8, Sentido1: 16.0
# Intervalo 9, Sentido0: 45.0
# Intervalo 9, Sentido1: 0.0
# Intervalo 10, Sentido0: 45.0
# Intervalo 10, Sentido1: 0.0
# Intervalo 11, Sentido0: 24.0
# Intervalo 11, Sentido1: 0.0
# Intervalo 12, Sentido0: 23.0
# Intervalo 12, Sentido1: 45.0
# Intervalo 13, Sentido0: 24.0
# Intervalo 13, Sentido1: 45.0
# Intervalo 14, Sentido0: 24.0
# Intervalo 14, Sentido1: 38.0
# Intervalo 15, Sentido0: 0.0
# Intervalo 15, Sentido1: 26.0
# Intervalo 16, Sentido0: 0.0
# Intervalo 16, Sentido1: 27.0
# Intervalo 17, Sentido0: 0.0
# Intervalo 17, Sentido1: 29.0
# Intervalo 18, Sentido0: 45.0
# Intervalo 18, Sentido1: 30.0
# Intervalo 19, Sentido0: 45.0
# Intervalo 19, Sentido1: 30.0
# Intervalo 20, Sentido0: 45.0
# Intervalo 20, Sentido1: 0.0
# Intervalo 21, Sentido0: 45.0
# Intervalo 21, Sentido1: 45.0
# Intervalo 22, Sentido0: 34.0
# Intervalo 22, Sentido1: 45.0
# Intervalo 23, Sentido0: 28.0
# Intervalo 23, Sentido1: 39.0
# Intervalo 24, Sentido0: 0.0
# Intervalo 24, Sentido1: 33.0
# Intervalo 25, Sentido0: 0.0
# Intervalo 25, Sentido1: 33.0
# Intervalo 26, Sentido0: 0.0
# Intervalo 26, Sentido1: 33.0
# Intervalo 27, Sentido0: 45.0
# Intervalo 27, Sentido1: 33.0
# Intervalo 28, Sentido0: 45.0
# Intervalo 28, Sentido1: 33.0
# Intervalo 29, Sentido0: 45.0
# Intervalo 67, Sentido0: 45.0
# Intervalo 67, Sentido1: 45.0
# Intervalo 68, Sentido0: 45.0
# Intervalo 68, Sentido1: 45.0
# Intervalo 69, Sentido0: 0.0
# Intervalo 69, Sentido1: 45.0
# Intervalo 70, Sentido0: 0.0
# Intervalo 70, Sentido1: 45.0
# Intervalo 71, Sentido0: 0.0
# Intervalo 71, Sentido1: 45.0
# Intervalo 72, Sentido0: 45.0
# Intervalo 72, Sentido1: 45.0
# Intervalo 73, Sentido0: 45.0
# Intervalo 73, Sentido1: 45.0
# Intervalo 74, Sentido0: 45.0
# Intervalo 74, Sentido1: 0.0
# Intervalo 75, Sentido0: 45.0
# Intervalo 75, Sentido1: 45.0
# Intervalo 76, Sentido0: 45.0
# Intervalo 76, Sentido1: 45.0
# Intervalo 77, Sentido0: 45.0
# Intervalo 77, Sentido1: 45.0
# Intervalo 78, Sentido0: 0.0
# Intervalo 78, Sentido1: 45.0
# Intervalo 79, Sentido0: 0.0
# Intervalo 79, Sentido1: 45.0
# Intervalo 80, Sentido0: 0.0
# Intervalo 80, Sentido1: 45.0
# Intervalo 81, Sentido0: 45.0
# Intervalo 81, Sentido1: 45.0
# Intervalo 82, Sentido0: 45.0
# Intervalo 82, Sentido1: 45.0
# Intervalo 83, Sentido0: 45.0
# Intervalo 83, Sentido1: 0.0
# Intervalo 84, Sentido0: 45.0
# Intervalo 84, Sentido1: 45.0
# Intervalo 85, Sentido0: 45.0
# Intervalo 85, Sentido1: 45.0
# Intervalo 86, Sentido0: 45.0
# Intervalo 86, Sentido1: 45.0
# Intervalo 87, Sentido0: 0.0
# Intervalo 87, Sentido1: 45.0
# Intervalo 88, Sentido0: 0.0
# Intervalo 88, Sentido1: 45.0
# Intervalo 89, Sentido0: 0.0
# Intervalo 89, Sentido1: 45.0
# Intervalo 90, Sentido0: 45.0
# Intervalo 90, Sentido1: 45.0
# Intervalo 91, Sentido0: 38.0
# Intervalo 91, Sentido1: 45.0
# Intervalo 92, Sentido0: 0.0
# Intervalo 92, Sentido1: 0.0
# Intervalo 93, Sentido0: 0.0
# Intervalo 93, Sentido1: 0.0
# Intervalo 94, Sentido0: 0.0
# Intervalo 94, Sentido1: 0.0
# Intervalo 95, Sentido0: 0.0
# Intervalo 95, Sentido1: 0.0
#
# Pasajeros que llegaron:
# Intervalo 0, Sentido0, : 8.0
# Intervalo 0, Sentido1, : 8.0
# Intervalo 1, Sentido0, : 10.0
# Intervalo 1, Sentido1, : 9.0
# Intervalo 2, Sentido0, : 11.0
# Intervalo 2, Sentido1, : 10.0
# Intervalo 3, Sentido0, : 13.0
# Intervalo 3, Sentido1, : 11.0
# Intervalo 4, Sentido0, : 14.0
# Intervalo 4, Sentido1, : 12.0
# Intervalo 5, Sentido0, : 16.0
# Intervalo 5, Sentido1, : 14.0
# Intervalo 6, Sentido0, : 17.0
# Intervalo 6, Sentido1, : 15.0
# Intervalo 7, Sentido0, : 18.0
# Intervalo 79, Sentido0, : 29.0
# Intervalo 79, Sentido1, : 26.0
# Intervalo 80, Sentido0, : 27.0
# Intervalo 80, Sentido1, : 26.0
# Intervalo 81, Sentido0, : 26.0
# Intervalo 81, Sentido1, : 25.0
# Intervalo 82, Sentido0, : 25.0
# Intervalo 82, Sentido1, : 24.0
# Intervalo 83, Sentido0, : 23.0
# Intervalo 83, Sentido1, : 24.0
# Intervalo 84, Sentido0, : 22.0
# Intervalo 84, Sentido1, : 23.0
# Intervalo 85, Sentido0, : 21.0
# Intervalo 85, Sentido1, : 22.0
# Intervalo 86, Sentido0, : 19.0
# Intervalo 86, Sentido1, : 21.0
# Intervalo 87, Sentido0, : 18.0
# Intervalo 87, Sentido1, : 20.0
# Intervalo 88, Sentido0, : 16.0
# Intervalo 88, Sentido1, : 18.0
# Intervalo 89, Sentido0, : 15.0
# Intervalo 89, Sentido1, : 17.0
# Intervalo 90, Sentido0, : 14.0
# Intervalo 90, Sentido1, : 16.0
# Intervalo 91, Sentido0, : 12.0
# Intervalo 91, Sentido1, : 14.0
# Intervalo 92, Sentido0, : 11.0
# Intervalo 92, Sentido1, : 13.0
# Intervalo 93, Sentido0, : 10.0
# Intervalo 93, Sentido1, : 11.0
# Intervalo 94, Sentido0, : 9.0
# Intervalo 94, Sentido1, : 10.0
# Intervalo 95, Sentido0, : 8.0
# Intervalo 95, Sentido1, : 8.0
#
# Pasajeros esperando por intervalo y sentido:
# Intervalo 0, Sentido0: 8.0
# Intervalo 0, Sentido1: 8.0
# Intervalo 1, Sentido0: 0.0
# Intervalo 1, Sentido1: 0.0
# Intervalo 2, Sentido0: 0.0
# Intervalo 2, Sentido1: 0.0
# Intervalo 3, Sentido0: 0.0
# Intervalo 3, Sentido1: 0.0
# Intervalo 4, Sentido0: 0.0
# Intervalo 4, Sentido1: 0.0
# Intervalo 5, Sentido0: 0.0
# Intervalo 5, Sentido1: 0.0
# Intervalo 6, Sentido0: 16.0
# Intervalo 6, Sentido1: 0.0
# Intervalo 7, Sentido0: 33.0
# Intervalo 7, Sentido1: 0.0
# Intervalo 8, Sentido0: 51.0
# Intervalo 8, Sentido1: 0.0
# Intervalo 9, Sentido0: 26.0
# Intervalo 9, Sentido1: 18.0
# Intervalo 10, Sentido0: 2.0
# Intervalo 10, Sentido1: 37.0
# Intervalo 11, Sentido0: 0.0
# Intervalo 11, Sentido1: 58.0
# Intervalo 12, Sentido0: 0.0
# Intervalo 12, Sentido1: 35.0
# Intervalo 13, Sentido0: 0.0
# Intervalo 13, Sentido1: 13.0
# Intervalo 14, Sentido0: 0.0
# Intervalo 14, Sentido1: 0.0
# Intervalo 15, Sentido0: 25.0
# Intervalo 15, Sentido1: 0.0
# Intervalo 16, Sentido0: 51.0
# Intervalo 16, Sentido1: 0.0
# Intervalo 17, Sentido0: 77.0
# Intervalo 17, Sentido1: 0.0
# Intervalo 18, Sentido0: 59.0
# Intervalo 18, Sentido1: 0.0
# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Parámetros de la gráfica
intervalos = list(range(m))  # Intervalos en el eje horizontal
colors = plt.cm.tab10(np.linspace(0, 1, n[0]))  # Colores para cada bus en el sentido f=0

# Graficar solo el sentido f=0
plt.figure(figsize=(12, 6))

for i in range(n[0]):  # Solo buses en el sentido f=0
    # Obtén el valor de cada variable de PuLP en x para sentido 0
    despachos = [x[(i, t, 0)].value() for t in intervalos]  # Extrae los valores de 0 o 1

    # Filtra solo los intervalos donde hay despacho (valor 1)
    intervalos_despachados = [t for t in intervalos if despachos[t] == 1]

    # Graficar los puntos para los intervalos despachados en la posición vertical del bus
    plt.scatter(intervalos_despachados, [i] * len(intervalos_despachados), color=colors[i], label=f'Bus {i}', s=100)

# Etiquetas y leyenda
plt.yticks(range(n[0]), [f'Bus {i}' for i in range(n[0])])  # Etiquetas del eje y
plt.xticks(range(0, m, 2))
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Despacho del bus")
plt.title("Despacho de buses en el sentido 1 por intervalos de tiempo")
plt.ylim(-0.5, n[0] - 0.5)  # Ajustar límites del eje y
plt.show()



# Mostrar la gráfica
plt.show()

# %%
# Parámetros de la gráfica
intervalos = list(range(m))  # Intervalos en el eje horizontal
colors = plt.cm.tab10(np.linspace(0, 1, n[1]))  # Colores para cada bus en el sentido f=1

# Graficar solo el sentido f=1
plt.figure(figsize=(12, 6))

for i in range(n[1]):  # Solo buses en el sentido f=1
    # Obtén el valor de cada variable de PuLP en x para sentido 1
    despachos = [x[(i, t, 1)].value() for t in intervalos]  # Extrae los valores de 0 o 1

    # Filtra solo los intervalos donde hay despacho (valor 1)
    intervalos_despachados = [t for t in intervalos if despachos[t] == 1]

    # Graficar los puntos para los intervalos despachados en la posición vertical del bus
    plt.scatter(intervalos_despachados, [i] * len(intervalos_despachados), color=colors[i], label=f'Bus {i}', s=100)

# Etiquetas y leyenda
plt.yticks(range(n[1]), [f'Bus {i}' for i in range(n[1])])  # Etiquetas del eje y
plt.xticks(range(0, m, 2))
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Despacho del bus")
plt.title("Despacho de buses en el sentido 2 por intervalos de tiempo")
plt.ylim(-0.5, n[1] - 0.5)  # Ajustar límites del eje y
plt.show()



# Mostrar la gráfica
plt.show()

# %%
abordando_sentido_0 = [b[t, 0].value() for t in range(m)]  # Espera en cada intervalo para f=0


# Configurar los intervalos en el eje x
intervalos = list(range(m))

# Crear la gráfica
plt.figure(figsize=(12, 6))
plt.plot(intervalos, abordando_sentido_0, label="Sentido f=0", color="blue", marker='*')


# Etiquetas y título
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Personas abordando")
plt.title("Personas abordando por intervalo en el sentido 1")

plt.xticks(range(0, m, 2))  # Mostrar etiquetas en el eje x cada 2 intervalos


# Mostrar la gráfica
plt.show()

# %%
abordando_sentido_1 = [b[t, 1].value() for t in range(m)]  # Espera en cada intervalo para f=1


# Configurar los intervalos en el eje x
intervalos = list(range(m))

# Crear la gráfica
plt.figure(figsize=(12, 6))
plt.plot(intervalos, abordando_sentido_1, label="Sentido f=0", color="red", marker='*')


# Etiquetas y título
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Personas abordando")
plt.title("Personas abordando por intervalo en el sentido 2")

plt.xticks(range(0, m, 2))  # Mostrar etiquetas en el eje x cada 2 intervalos


# Mostrar la gráfica
plt.show()

# %%
pasajeros_esperando_0 = [w[(t, 0)].value() for t in range(m)]

# Crear la gráfica
plt.figure(figsize=(12, 6))
plt.plot(range(m), pasajeros_esperando_0, linestyle='-', marker="*",color='g', label='Pasajeros abordando (f=0)')

# Configuración de ejes y etiquetas
plt.xticks(range(0, m, 2))  # Mostrar etiquetas en el eje x de dos en dos
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Número de pasajeros esperando")
plt.title("Número de pasajeros esperando en cada intervalo en el sentido 1")

# Mostrar la gráfica
plt.show()

# %%
pasajeros_esperando_1 = [w[(t, 1)].value() for t in range(m)]

# Crear la gráfica
plt.figure(figsize=(12, 6))
plt.plot(range(m), pasajeros_esperando_1, linestyle='-', marker="*",color='orange', label='Pasajeros abordando (f=1)')

# Configuración de ejes y etiquetas
plt.xticks(range(0, m, 2))  # Mostrar etiquetas en el eje x de dos en dos
plt.xlabel("Intervalo de tiempo t")
plt.ylabel("Número de pasajeros esperando")
plt.title("Número de pasajeros esperando en cada intervalo en el sentido 2")

# Mostrar la gráfica
plt.show()

# %%
# Datos para la tabla
data = [
    [1, 13, 1951, 48, "77.69s"],
    [2, 12, 1501, 48, "72.61s"],
    [3, 11, 1086, 48, "67.78s"],
    [4, 10, 707, 48, "350.03s"],
    [5,9,302,48,"132.08s"],
    [6,8,42,128,"623.06s"],
    [7,7,42,492,"1043.63s"],
    [8,6,42,829,"491.96s"],
]

# Encabezados de las columnas
column_labels = ["n1", "n2", "w1", "w2", "CPU time"]

# Crear la figura y la tabla
fig, ax = plt.subplots(figsize=(8, 4))
ax.axis("off")  # Ocultar los ejes
table = ax.table(cellText=data, colLabels=column_labels, cellLoc='center', loc='center')
# Ajustar el estilo de las líneas
for i in range(len(data) + 1):  # +1 para incluir la fila de encabezado
    for j in range(len(column_labels)):
        cell = table[(i, j)]
        # Para la primera fila (encabezado), mostrar superior y verticales
        if i == 0:
            cell.visible_edges = 'LTR'  # Borde izquierdo, derecho y superior
        # Para la última fila, mostrar inferior y verticales
        elif i == len(data):
            cell.visible_edges = 'LBR'  # Borde izquierdo, derecho y inferior
        # Para las filas intermedias, solo bordes verticales
        else:
            cell.visible_edges = 'LR'

# Escalar la tabla para mejor visualización
table.scale(1, 1.5)  # Escalar la tabla si es necesario para mejor visualización
plt.text(0.5, 1, "c = 45, h_min = 5m, h_max = 15m", ha='center', va='center', fontsize=12, transform=ax.transAxes)
# Mostrar la tabla
plt.show()
